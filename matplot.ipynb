# %%
import matplotlib.pyplot as plt
a = plt.plot([1,2,3,4])
b = plt.ylabel('some numbers')
c = plt.xlabel('some indeces')
d = plt.plot([0.5, 1.1, 2.1, 3.4])

# %%
print (a)
print (b)
print (c)
print (d)
plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x0000029248018F98>]
# Text(17.2,0.5,'some numbers')
# Text(0.5,17.2,'some indeces')
# [<matplotlib.lines.Line2D object at 0x0000029248020470>]

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triagles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')

# label 만들기
b = plt.ylabel('some numbers')
c = plt.xlabel('some indeces')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c, s = np.cos(x), np.sin(x)

pt1 = plt.plot(x,c)
pt2 = plt.plot(x,s)

print (pt1), (pt2)


plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x0000029248218B70>]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c, s = np.cos(x), np.sin(x)

fig1 = plt.figure(1)
pt1 = plt.plot(x,c)
fig2 = plt.figure(2)
pt2 = plt.plot(x,s)

print (pt1), (pt2)
print (fig1), (fig2)

plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x0000029247F7C390>]
# Figure(432x288)

# %%
import numpy as np
import matplotlib.pyplot as plt
x1 = [1,2,3,4,5]
y1 = [1,4,9,16,25]
x2 = [1,2,4,6,8]
y2 = [2,4,8,12,16]

plt.plot(x1,y1,'r')
plt.plot(x2,y2,'g')

plt.title('Plot of y vs. x')

plt.xlabel('x axis')
plt.ylabel('y axis')

plt.xlim(0.0, 9.0)
plt.xlim(0.0, 30.)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

a = b = np.arange(0,3,.02)
c = np.exp(a)
d = c[::-1]

plt.plot(a,c,'k--',)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
line1, line2 = plt.plot(x,y,'-',x,y*2,'--')
print (line1)
print (line2)

plt.setp(line1, color = 'r', linewidth='2.0')

plt.show()
# Out:
# Line2D(_line0)
# Line2D(_line1)

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.rand(10,2)
print (data)
print (data.shape)

plt.scatter(data[:,0], data[:,1])
plt.show()
# Out:
# [[0.56725048 0.28048633]
#  [0.78397225 0.10226103]
#  [0.17599151 0.49076903]
#  [0.61546379 0.61364322]
#  [0.69959631 0.63261753]
#  [0.94044562 0.35118603]
#  [0.64783492 0.65144528]
#  [0.75864638 0.44117936]
#  [0.87802133 0.72407571]
#  [0.03671201 0.51165537]]
# (10, 2)

# %%
x = np.random.rand(10)
y = np.random.rand(10)
z = np.sqrt(x**2, y**2)

plt.bar
# Out:
# <function matplotlib.pyplot.bar(*args, **kwargs)>

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(5.0, 3.0, 1000)
plt.hist(data)

plt.xlabel('data')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.randn(1000)
plt.hist(x, bins=20)
plt.show()
